# %% [markdown]
# # WearableSignalLab Demo
#
# Run the scripts in order to reproduce the first version of the pipeline:
#
# ```bash
# python3 scripts/01_prepare_data.py
# python3 scripts/02_filter_and_features.py
# python3 scripts/03_train_baseline.py
# python3 scripts/04_make_figures.py
# ```
#
# This notebook is intentionally minimal. The main reproducible workflow lives in `scripts/`.
